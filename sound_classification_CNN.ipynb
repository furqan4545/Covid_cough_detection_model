# %% [markdown]
# # WORKING CODE WITH 3 MODELS

# %% [markdown]
# * MODEL 1:

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

DATASET_PATH = "data.json"

def load_data(dataset_path):
    with open(dataset_path, "r") as fp:
        data = json.load(fp)
        
        
    # converting lists into numpy arrays
    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    
    return X, y

def plot_history(history):
    
    fig, axis = plt.subplots(2)
    
    # create accuracy subplot
    axis[0].plot(history.history["accuracy"], label = "train accuracy" )
    axis[0].plot(history.history["val_accuracy"], label = "test_accuracy" )
    axis[0].set_ylabel("Accuracy")
    axis[0].set_xlabel("Epochs")
    axis[0].legend(loc = "lower right")
    axis[0].set_title("Acccuracy eval")
    
    
    # create error subplot
    axis[1].plot(history.history["loss"], label = "train error" )
    axis[1].plot(history.history["val_loss"], label = "test error" )
    axis[1].set_ylabel("Error")
    axis[1].set_xlabel("Epochs")
    axis[1].legend(loc = "upper right")
    axis[1].set_title("Error eval")
    
    plt.show()

def prepare_datasets(test_size, validation_size):
    
    # load dataset
    X, y = load_data(DATASET_PATH)
    
    # create train/test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = test_size)
    
    # create train/validataion split
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size= validation_size)
    
    print(X_train.shape)
    
    # so in X_train we have 3d array --> (sample_size, mfcc_vector, mfcc_coefficient)
    # so we have to introduce another dimension in it. and make it 4d array. 
    X_train = X_train[... , np.newaxis]
    # ... 3dots mean keep the rest of the shape same.
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]
    
    print(X_train.shape)
    print(X_validation.shape)
    print(X_test.shape)
    
    
    return X_train, X_validation, X_test, y_train, y_validation, y_test
    

def build_model(input_shape):
    
    # create model
    model = keras.Sequential()
    
    # 1st conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), padding='same', activation = "relu", input_shape = input_shape))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
#     model.add(keras.layers.MaxPooling2D(pool_size=(3, 3)))
    model.add(keras.layers.BatchNormalization())
    
    # 2nd conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), padding='same', activation = "relu"))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
#     model.add(keras.layers.MaxPooling2D(pool_size=(3, 3)))
    model.add(keras.layers.BatchNormalization())
    
    # 3rd conv layer
    model.add(keras.layers.Conv2D(32, (2, 2), padding='same', activation = "relu"))
    model.add(keras.layers.MaxPooling2D((2, 2), strides=(2, 2), padding='same'))
#     model.add(keras.layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(keras.layers.BatchNormalization())
    
    # 4th conv layer
    model.add(keras.layers.Conv2D(32, (2, 2), padding='same', activation = "relu"))
    model.add(keras.layers.BatchNormalization())

    # Flatten the output and feed it into dense layer
    model.add(keras.layers.Flatten())
    
    # 1st dense layer
    model.add(keras.layers.Dense(128, activation = "relu", kernel_regularizer=keras.regularizers.l2(0.001)))
    model.add(keras.layers.Dropout(0.5))
    
    # 2nd dense layer
    model.add(keras.layers.Dense(64, activation = "relu", kernel_regularizer=keras.regularizers.l2(0.001)))
    model.add(keras.layers.Dropout(0.5))
    
    # output layer
    model.add(keras.layers.Dense(10, activation = "softmax"))
    
    return model


def predict(model, X, y):
    """Predict a single sample using the trained model

    :param model: Trained classifier
    :param X: Input data
    :param y (int): Target
    """

    # add a dimension to input data for sample - model.predict() expects a 4d array in this case
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)

    # perform prediction
    prediction = model.predict(X)

    # get index with max value
    predicted_index = np.argmax(prediction, axis=1)

    print("Target: {}, Predicted label: {}".format(y, predicted_index))



if __name__ == "__main__":

    # Create train, validation and test set
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.20)
#     X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

    
    input_shape = (X_train.shape[1], X_train.shape[2], 1)
    
    # build the CNN network architecture
    model = build_model(input_shape)
    
    # compile the network
    optimizer = keras.optimizers.Adam(learning_rate = 0.001)
    model.compile(optimizer = optimizer,
                  loss = "sparse_categorical_crossentropy",
                  metrics = ["accuracy"]
                 )
    
    model.summary()
    
    # train the CNN
    history = model.fit(X_train,
              y_train,
              validation_data = (X_validation, y_validation),
              batch_size = 32,
              epochs = 30
             )
    
    # plot accuracy/error for training and validation
    plot_history(history)
    
    # evaluate the CNN on the test set
    test_error, test_accuracy = model.evaluate(X_test, y_test, verbose = 1)
    print("Accuracy on test set is {}".format(test_accuracy))
    
    # pick a sample to predict from the test set
    X_to_predict = X_test[50]
    y_to_predict = y_test[50]

    # predict sample
    predict(model, X_to_predict, y_to_predict)
# Out:
# (5997, 130, 13)
# (5997, 130, 13, 1)
# (1500, 130, 13, 1)
# (2499, 130, 13, 1)
# Model: "sequential_52"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_143 (Conv2D)          (None, 130, 13, 32)       320
# _________________________________________________________________
# max_pooling2d_114 (MaxPoolin (None, 65, 7, 32)         0
# _________________________________________________________________
# batch_normalization_117 (Bat (None, 65, 7, 32)         128
# _________________________________________________________________
# conv2d_144 (Conv2D)          (None, 65, 7, 32)         9248
# _________________________________________________________________
# max_pooling2d_115 (MaxPoolin (None, 33, 4, 32)         0
# _________________________________________________________________
# batch_normalization_118 (Bat (None, 33, 4, 32)         128
# _________________________________________________________________
# conv2d_145 (Conv2D)          (None, 33, 4, 32)         4128
# _________________________________________________________________
# max_pooling2d_116 (MaxPoolin (None, 17, 2, 32)         0
# _________________________________________________________________
# batch_normalization_119 (Bat (None, 17, 2, 32)         128
# _________________________________________________________________
# conv2d_146 (Conv2D)          (None, 17, 2, 32)         4128
# _________________________________________________________________
# batch_normalization_120 (Bat (None, 17, 2, 32)         128
# _________________________________________________________________
# flatten_20 (Flatten)         (None, 1088)              0
# _________________________________________________________________
# dense_64 (Dense)             (None, 128)               139392
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_65 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_66 (Dense)             (None, 10)                650
# =================================================================
# Total params: 166,634
# Trainable params: 166,378
# Non-trainable params: 256
# _________________________________________________________________
# Train on 5997 samples, validate on 1500 samples
# Epoch 1/30
# 5997/5997 [==============================] - 21s 4ms/sample - loss: 2.1081 - accuracy: 0.3643 - val_loss: 1.7616 - val_accuracy: 0.4867
# Epoch 2/30
# 5997/5997 [==============================] - 15s 2ms/sample - loss: 1.7169 - accuracy: 0.4954 - val_loss: 1.4875 - val_accuracy: 0.5613
# Epoch 3/30
# 5997/5997 [==============================] - 15s 2ms/sample - loss: 1.5194 - accuracy: 0.5603 - val_loss: 1.3307 - val_accuracy: 0.6027
# Epoch 4/30
# 5997/5997 [==============================] - 15s 2ms/sample - loss: 1.3302 - accuracy: 0.6228 - val_loss: 1.2825 - val_accuracy: 0.6407
# Epoch 5/30
# 5997/5997 [==============================] - 15s 3ms/sample - loss: 1.2209 - accuracy: 0.6532 - val_loss: 1.2167 - val_accuracy: 0.6387
# Epoch 6/30
# 5997/5997 [==============================] - 15s 2ms/sample - loss: 1.1378 - accuracy: 0.6865 - val_loss: 1.1439 - val_accuracy: 0.6827
# Epoch 7/30
# 5997/5997 [==============================] - 15s 2ms/sample - loss: 1.0462 - accuracy: 0.7072 - val_loss: 1.2488 - val_accuracy: 0.6567
# Epoch 8/30
# 5997/5997 [==============================] - 15s 2ms/sample - loss: 0.9889 - accuracy: 0.7279 - val_loss: 1.1051 - val_accuracy: 0.7053
# Epoch 9/30
# 5997/5997 [==============================] - 15s 2ms/sample - loss: 0.9090 - accuracy: 0.7549 - val_loss: 1.0312 - val_accuracy: 0.7127
# Epoch 10/30
# 5997/5997 [==============================] - 15s 2ms/sample - loss: 0.8695 - accuracy: 0.7692 - val_loss: 0.9359 - val_accuracy: 0.7507
# Epoch 11/30
# 5997/5997 [==============================] - 15s 2ms/sample - loss: 0.8068 - accuracy: 0.7944 - val_loss: 0.9674 - val_accuracy: 0.7553
# Epoch 12/30
# 5997/5997 [==============================] - 15s 3ms/sample - loss: 0.7760 - accuracy: 0.8007 - val_loss: 1.0809 - val_accuracy: 0.7107
# Epoch 13/30
# 5997/5997 [==============================] - 15s 2ms/sample - loss: 0.7495 - accuracy: 0.8184 - val_loss: 1.1264 - val_accuracy: 0.6960
# Epoch 14/30
# 5997/5997 [==============================] - 15s 2ms/sample - loss: 0.6974 - accuracy: 0.8306 - val_loss: 1.2280 - val_accuracy: 0.7013
# Epoch 15/30
# 5997/5997 [==============================] - 15s 3ms/sample - loss: 0.6778 - accuracy: 0.8361 - val_loss: 1.1703 - val_accuracy: 0.7100
# Epoch 16/30
# 5997/5997 [==============================] - 15s 2ms/sample - loss: 0.6569 - accuracy: 0.8403 - val_loss: 1.1382 - val_accuracy: 0.7120
# Epoch 17/30
# 5997/5997 [==============================] - 15s 2ms/sample - loss: 0.6177 - accuracy: 0.8578 - val_loss: 1.0286 - val_accuracy: 0.7493
# Epoch 18/30
# 5997/5997 [==============================] - 15s 2ms/sample - loss: 0.5744 - accuracy: 0.8769 - val_loss: 1.1999 - val_accuracy: 0.7233
# Epoch 19/30
# 5997/5997 [==============================] - 15s 2ms/sample - loss: 0.5917 - accuracy: 0.8723 - val_loss: 1.3091 - val_accuracy: 0.6833
# Epoch 20/30
# 5997/5997 [==============================] - 15s 3ms/sample - loss: 0.5877 - accuracy: 0.8754 - val_loss: 1.4691 - val_accuracy: 0.6553
# Epoch 21/30
# 5997/5997 [==============================] - 15s 3ms/sample - loss: 0.5357 - accuracy: 0.8886 - val_loss: 1.1491 - val_accuracy: 0.7400
# Epoch 22/30
# 5997/5997 [==============================] - 15s 2ms/sample - loss: 0.5426 - accuracy: 0.8918 - val_loss: 1.3523 - val_accuracy: 0.7033
# Epoch 23/30
# 5997/5997 [==============================] - 15s 2ms/sample - loss: 0.5185 - accuracy: 0.8976 - val_loss: 1.1987 - val_accuracy: 0.7287
# Epoch 24/30
# 5997/5997 [==============================] - 15s 3ms/sample - loss: 0.5038 - accuracy: 0.9046 - val_loss: 1.2771 - val_accuracy: 0.7160
# Epoch 25/30
# 5997/5997 [==============================] - 15s 2ms/sample - loss: 0.5082 - accuracy: 0.9080 - val_loss: 1.3631 - val_accuracy: 0.7027
# Epoch 26/30
# 5997/5997 [==============================] - 15s 2ms/sample - loss: 0.4881 - accuracy: 0.9161 - val_loss: 1.1378 - val_accuracy: 0.7553
# Epoch 27/30
# 5997/5997 [==============================] - 15s 2ms/sample - loss: 0.4644 - accuracy: 0.9196 - val_loss: 1.1227 - val_accuracy: 0.7340
# Epoch 28/30
# 5997/5997 [==============================] - 15s 2ms/sample - loss: 0.4682 - accuracy: 0.9205 - val_loss: 1.0709 - val_accuracy: 0.7673
# Epoch 29/30
# 5997/5997 [==============================] - 15s 2ms/sample - loss: 0.4446 - accuracy: 0.9280 - val_loss: 1.1318 - val_accuracy: 0.7660
# Epoch 30/30
# 5997/5997 [==============================] - 15s 2ms/sample - loss: 0.4573 - accuracy: 0.9275 - val_loss: 1.1209 - val_accuracy: 0.7647
# 2499/2499 [==============================] - 1s 496us/sample - loss: 1.1271 - accuracy: 0.7643
# Accuracy on test set is 0.7643057107925415
# Target: 5, Predicted label: [5]

# %% [markdown]
# # ANOTHER EXAMPLE

# %% [markdown]
# * MODEL 2:

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

DATA_PATH = "data.json"


def load_data(data_path):
    """Loads training dataset from json file.

        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    return X, y


def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs

        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()


def prepare_datasets(test_size, validation_size):
    """Loads data and splits it into train, validation and test sets.

    :param test_size (float): Value in [0, 1] indicating percentage of data set to allocate to test split
    :param validation_size (float): Value in [0, 1] indicating percentage of train set to allocate to validation split

    :return X_train (ndarray): Input training set
    :return X_validation (ndarray): Input validation set
    :return X_test (ndarray): Input test set
    :return y_train (ndarray): Target training set
    :return y_validation (ndarray): Target validation set
    :return y_test (ndarray): Target test set
    """

    # load data
    X, y = load_data(DATA_PATH)

    # create train, validation and test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # add an axis to input sets
    X_train = X_train[..., np.newaxis]
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test


def build_model(input_shape):
    """Generates CNN model

    :param input_shape (tuple): Shape of input set
    :return model: CNN model
    """

    # build network topology
    model = keras.Sequential()

    # 1st conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 2nd conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu'))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 3rd conv layer
    model.add(keras.layers.Conv2D(32, (2, 2), activation='relu'))
    model.add(keras.layers.MaxPooling2D((2, 2), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # flatten output and feed it into dense layer
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dropout(0.3))

    # output layer
    model.add(keras.layers.Dense(10, activation='softmax'))

    return model


def predict(model, X, y):
    """Predict a single sample using the trained model

    :param model: Trained classifier
    :param X: Input data
    :param y (int): Target
    """

    # add a dimension to input data for sample - model.predict() expects a 4d array in this case
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)

    # perform prediction
    prediction = model.predict(X)

    # get index with max value
    predicted_index = np.argmax(prediction, axis=1)

    print("Target: {}, Predicted label: {}".format(y, predicted_index))


if __name__ == "__main__":

    # get train, validation, test splits
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2], 1)
    model = build_model(input_shape)

    # compile model
    optimizer = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimizer,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=32, epochs=30)

    # plot accuracy/error for training and validation
    plot_history(history)

    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)

    # pick a sample to predict from the test set
    X_to_predict = X_test[100]
    y_to_predict = y_test[100]

    # predict sample
    predict(model, X_to_predict, y_to_predict)
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_38 (Conv2D)           (None, 128, 11, 32)       320
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 64, 6, 32)         0
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 64, 6, 32)         128
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 62, 4, 32)         9248
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 31, 2, 32)         0
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 31, 2, 32)         128
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 30, 1, 32)         4128
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 15, 1, 32)         0
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 15, 1, 32)         128
# _________________________________________________________________
# flatten (Flatten)            (None, 480)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                30784
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 45,514
# Trainable params: 45,322
# Non-trainable params: 192
# _________________________________________________________________
# Train on 5997 samples, validate on 1500 samples
# Epoch 1/30
# 5997/5997 [==============================] - 20s 3ms/sample - loss: 2.4049 - accuracy: 0.2375 - val_loss: 1.8283 - val_accuracy: 0.3740
# Epoch 2/30
# 5997/5997 [==============================] - 11s 2ms/sample - loss: 1.8124 - accuracy: 0.3780 - val_loss: 1.5092 - val_accuracy: 0.4660
# Epoch 3/30
# 5997/5997 [==============================] - 10s 2ms/sample - loss: 1.5920 - accuracy: 0.4411 - val_loss: 1.3749 - val_accuracy: 0.5033
# Epoch 4/30
# 5997/5997 [==============================] - 11s 2ms/sample - loss: 1.4851 - accuracy: 0.4732 - val_loss: 1.2701 - val_accuracy: 0.5260
# Epoch 5/30
# 5997/5997 [==============================] - 10s 2ms/sample - loss: 1.3880 - accuracy: 0.5033 - val_loss: 1.2143 - val_accuracy: 0.5433
# Epoch 6/30
# 5997/5997 [==============================] - 11s 2ms/sample - loss: 1.3185 - accuracy: 0.5303 - val_loss: 1.1669 - val_accuracy: 0.5567
# Epoch 7/30
# 5997/5997 [==============================] - 11s 2ms/sample - loss: 1.2671 - accuracy: 0.5543 - val_loss: 1.1166 - val_accuracy: 0.5793
# Epoch 8/30
# 5997/5997 [==============================] - 10s 2ms/sample - loss: 1.2007 - accuracy: 0.5773 - val_loss: 1.0785 - val_accuracy: 0.6007
# Epoch 9/30
# 5997/5997 [==============================] - 11s 2ms/sample - loss: 1.1548 - accuracy: 0.5866 - val_loss: 1.0496 - val_accuracy: 0.6167
# Epoch 10/30
# 5997/5997 [==============================] - 10s 2ms/sample - loss: 1.1200 - accuracy: 0.6061 - val_loss: 1.0283 - val_accuracy: 0.6240
# Epoch 11/30
# 5997/5997 [==============================] - 10s 2ms/sample - loss: 1.0868 - accuracy: 0.6113 - val_loss: 1.0030 - val_accuracy: 0.6367
# Epoch 12/30
# 5997/5997 [==============================] - 11s 2ms/sample - loss: 1.0483 - accuracy: 0.6241 - val_loss: 0.9803 - val_accuracy: 0.6380
# Epoch 13/30
# 5997/5997 [==============================] - 11s 2ms/sample - loss: 1.0268 - accuracy: 0.6422 - val_loss: 0.9569 - val_accuracy: 0.6527
# Epoch 14/30
# 5997/5997 [==============================] - 10s 2ms/sample - loss: 0.9970 - accuracy: 0.6528 - val_loss: 0.9430 - val_accuracy: 0.6540
# Epoch 15/30
# 5997/5997 [==============================] - 10s 2ms/sample - loss: 0.9704 - accuracy: 0.6647 - val_loss: 0.9280 - val_accuracy: 0.6560
# Epoch 16/30
# 5997/5997 [==============================] - 10s 2ms/sample - loss: 0.9554 - accuracy: 0.6672 - val_loss: 0.9039 - val_accuracy: 0.6673
# Epoch 17/30
# 5997/5997 [==============================] - 11s 2ms/sample - loss: 0.9133 - accuracy: 0.6847 - val_loss: 0.8925 - val_accuracy: 0.6713
# Epoch 18/30
# 5997/5997 [==============================] - 11s 2ms/sample - loss: 0.8911 - accuracy: 0.6905 - val_loss: 0.8757 - val_accuracy: 0.6827
# Epoch 19/30
# 5997/5997 [==============================] - 12s 2ms/sample - loss: 0.8753 - accuracy: 0.6857 - val_loss: 0.8555 - val_accuracy: 0.6887
# Epoch 20/30
# 5997/5997 [==============================] - 11s 2ms/sample - loss: 0.8395 - accuracy: 0.7109 - val_loss: 0.8421 - val_accuracy: 0.6953
# Epoch 21/30
# 5997/5997 [==============================] - 10s 2ms/sample - loss: 0.8324 - accuracy: 0.7122 - val_loss: 0.8376 - val_accuracy: 0.7027
# Epoch 22/30
# 5997/5997 [==============================] - 10s 2ms/sample - loss: 0.8228 - accuracy: 0.7142 - val_loss: 0.8510 - val_accuracy: 0.6927
# Epoch 23/30
# 5997/5997 [==============================] - 11s 2ms/sample - loss: 0.8044 - accuracy: 0.7152 - val_loss: 0.8439 - val_accuracy: 0.7067
# Epoch 24/30
# 5997/5997 [==============================] - 10s 2ms/sample - loss: 0.7801 - accuracy: 0.7275 - val_loss: 0.8110 - val_accuracy: 0.7160
# Epoch 25/30
# 5997/5997 [==============================] - 12s 2ms/sample - loss: 0.7581 - accuracy: 0.7382 - val_loss: 0.8064 - val_accuracy: 0.7133
# Epoch 26/30
# 5997/5997 [==============================] - 11s 2ms/sample - loss: 0.7396 - accuracy: 0.7479 - val_loss: 0.8238 - val_accuracy: 0.7100
# Epoch 27/30
# 5997/5997 [==============================] - 11s 2ms/sample - loss: 0.7276 - accuracy: 0.7464 - val_loss: 0.7923 - val_accuracy: 0.7073
# Epoch 28/30
# 5997/5997 [==============================] - 11s 2ms/sample - loss: 0.7324 - accuracy: 0.7409 - val_loss: 0.7823 - val_accuracy: 0.7180
# Epoch 29/30
# 5997/5997 [==============================] - 11s 2ms/sample - loss: 0.7182 - accuracy: 0.7504 - val_loss: 0.7657 - val_accuracy: 0.7320
# Epoch 30/30
# 5997/5997 [==============================] - 10s 2ms/sample - loss: 0.6923 - accuracy: 0.7555 - val_loss: 0.7609 - val_accuracy: 0.7333
# 2499/2499 - 1s - loss: 0.8239 - accuracy: 0.7171
#
# Test accuracy: 0.71708685
# Target: 1, Predicted label: [1]

# %% [markdown]
# # EXPERIMENT 3

# %% [markdown]
# * MODEL 3:

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

DATA_PATH = "sick_sound.json"


def load_data(data_path):
    """Loads training dataset from json file.

        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    return X, y


def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs

        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()


def prepare_datasets(test_size, validation_size):
    """Loads data and splits it into train, validation and test sets.

    :param test_size (float): Value in [0, 1] indicating percentage of data set to allocate to test split
    :param validation_size (float): Value in [0, 1] indicating percentage of train set to allocate to validation split

    :return X_train (ndarray): Input training set
    :return X_validation (ndarray): Input validation set
    :return X_test (ndarray): Input test set
    :return y_train (ndarray): Target training set
    :return y_validation (ndarray): Target validation set
    :return y_test (ndarray): Target test set
    """

    # load data
    X, y = load_data(DATA_PATH)

    # create train, validation and test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # add an axis to input sets
    X_train = X_train[..., np.newaxis]
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test


def build_model(input_shape):
    """Generates CNN model

    :param input_shape (tuple): Shape of input set
    :return model: CNN model
    """

    # build network topology
    model = keras.Sequential()

    # 1st conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 2nd conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu'))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 3rd conv layer
    model.add(keras.layers.Conv2D(32, (2, 2), activation='relu'))
    model.add(keras.layers.MaxPooling2D((2, 2), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # flatten output and feed it into dense layer
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dropout(0.3))

    # output layer
    model.add(keras.layers.Dense(2, activation='softmax'))

    return model


def predict(model, X, y):
    """Predict a single sample using the trained model

    :param model: Trained classifier
    :param X: Input data
    :param y (int): Target
    """

    # add a dimension to input data for sample - model.predict() expects a 4d array in this case
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)

    # perform prediction
    prediction = model.predict(X)

    # get index with max value
    predicted_index = np.argmax(prediction, axis=1)

    print("Target: {}, Predicted label: {}".format(y, predicted_index))


if __name__ == "__main__":

    # get train, validation, test splits
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2], 1)
    model = build_model(input_shape)

    # compile model
    optimizer = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimizer,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=32, epochs=30)

    # plot accuracy/error for training and validation
    plot_history(history)

    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)

    # pick a sample to predict from the test set
    X_to_predict = X_test[0]
    y_to_predict = y_test[0]

    # predict sample
    predict(model, X_to_predict, y_to_predict)
# Out:
# Model: "sequential_42"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_129 (Conv2D)          (None, 106, 11, 32)       320
# _________________________________________________________________
# max_pooling2d_104 (MaxPoolin (None, 53, 6, 32)         0
# _________________________________________________________________
# batch_normalization_104 (Bat (None, 53, 6, 32)         128
# _________________________________________________________________
# conv2d_130 (Conv2D)          (None, 51, 4, 32)         9248
# _________________________________________________________________
# max_pooling2d_105 (MaxPoolin (None, 26, 2, 32)         0
# _________________________________________________________________
# batch_normalization_105 (Bat (None, 26, 2, 32)         128
# _________________________________________________________________
# conv2d_131 (Conv2D)          (None, 25, 1, 32)         4128
# _________________________________________________________________
# max_pooling2d_106 (MaxPoolin (None, 13, 1, 32)         0
# _________________________________________________________________
# batch_normalization_106 (Bat (None, 13, 1, 32)         128
# _________________________________________________________________
# flatten_17 (Flatten)         (None, 416)               0
# _________________________________________________________________
# dense_37 (Dense)             (None, 64)                26688
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_38 (Dense)             (None, 10)                650
# =================================================================
# Total params: 41,418
# Trainable params: 41,226
# Non-trainable params: 192
# _________________________________________________________________
# Train on 4909 samples, validate on 1228 samples
# Epoch 1/30
# 4909/4909 [==============================] - 16s 3ms/sample - loss: 2.2171 - accuracy: 0.2931 - val_loss: 1.4131 - val_accuracy: 0.5945
# Epoch 2/30
# 4909/4909 [==============================] - 7s 1ms/sample - loss: 1.2258 - accuracy: 0.5842 - val_loss: 0.8603 - val_accuracy: 0.6946
# Epoch 3/30
# 4909/4909 [==============================] - 7s 1ms/sample - loss: 0.9127 - accuracy: 0.6580 - val_loss: 0.7102 - val_accuracy: 0.6995
# Epoch 4/30
# 4909/4909 [==============================] - 8s 2ms/sample - loss: 0.8162 - accuracy: 0.6712 - val_loss: 0.6661 - val_accuracy: 0.7125
# Epoch 5/30
# 4909/4909 [==============================] - 7s 1ms/sample - loss: 0.7280 - accuracy: 0.6826 - val_loss: 0.6328 - val_accuracy: 0.7085
# Epoch 6/30
# 4909/4909 [==============================] - 7s 1ms/sample - loss: 0.6874 - accuracy: 0.7063 - val_loss: 0.6086 - val_accuracy: 0.7182
# Epoch 7/30
# 4909/4909 [==============================] - 7s 1ms/sample - loss: 0.6413 - accuracy: 0.7238 - val_loss: 0.5984 - val_accuracy: 0.7158
# Epoch 8/30
# 4909/4909 [==============================] - 7s 1ms/sample - loss: 0.6237 - accuracy: 0.7189 - val_loss: 0.5862 - val_accuracy: 0.7182
# Epoch 9/30
# 4909/4909 [==============================] - 7s 1ms/sample - loss: 0.6004 - accuracy: 0.7221 - val_loss: 0.5830 - val_accuracy: 0.7191
# Epoch 10/30
# 4909/4909 [==============================] - 7s 1ms/sample - loss: 0.5743 - accuracy: 0.7397 - val_loss: 0.5829 - val_accuracy: 0.7256
# Epoch 11/30
# 4909/4909 [==============================] - 7s 1ms/sample - loss: 0.5493 - accuracy: 0.7488 - val_loss: 0.5642 - val_accuracy: 0.7296
# Epoch 12/30
# 4909/4909 [==============================] - 7s 1ms/sample - loss: 0.5368 - accuracy: 0.7517 - val_loss: 0.5673 - val_accuracy: 0.7296
# Epoch 13/30
# 4909/4909 [==============================] - 7s 1ms/sample - loss: 0.5231 - accuracy: 0.7568 - val_loss: 0.5583 - val_accuracy: 0.7362
# Epoch 14/30
# 4909/4909 [==============================] - 7s 1ms/sample - loss: 0.5112 - accuracy: 0.7670 - val_loss: 0.5514 - val_accuracy: 0.7378
# Epoch 15/30
# 4909/4909 [==============================] - 7s 1ms/sample - loss: 0.4988 - accuracy: 0.7737 - val_loss: 0.5556 - val_accuracy: 0.7378
# Epoch 16/30
# 4909/4909 [==============================] - 7s 1ms/sample - loss: 0.4819 - accuracy: 0.7761 - val_loss: 0.5466 - val_accuracy: 0.7337
# Epoch 17/30
# 4909/4909 [==============================] - 7s 1ms/sample - loss: 0.4650 - accuracy: 0.7916 - val_loss: 0.5506 - val_accuracy: 0.7443
# Epoch 18/30
# 4909/4909 [==============================] - 7s 1ms/sample - loss: 0.4607 - accuracy: 0.7875 - val_loss: 0.5638 - val_accuracy: 0.7435
# Epoch 19/30
# 4909/4909 [==============================] - 7s 1ms/sample - loss: 0.4467 - accuracy: 0.7973 - val_loss: 0.5415 - val_accuracy: 0.7394
# Epoch 20/30
# 4909/4909 [==============================] - 7s 1ms/sample - loss: 0.4417 - accuracy: 0.7973 - val_loss: 0.5507 - val_accuracy: 0.7386
# Epoch 21/30
# 4909/4909 [==============================] - 7s 1ms/sample - loss: 0.4339 - accuracy: 0.8014 - val_loss: 0.5608 - val_accuracy: 0.7410
# Epoch 22/30
# 4909/4909 [==============================] - 7s 1ms/sample - loss: 0.4318 - accuracy: 0.8057 - val_loss: 0.5550 - val_accuracy: 0.7435
# Epoch 23/30
# 4909/4909 [==============================] - 7s 1ms/sample - loss: 0.4252 - accuracy: 0.8095 - val_loss: 0.5452 - val_accuracy: 0.7378
# Epoch 24/30
# 4909/4909 [==============================] - 7s 1ms/sample - loss: 0.4086 - accuracy: 0.8207 - val_loss: 0.5492 - val_accuracy: 0.7451
# Epoch 25/30
# 4909/4909 [==============================] - 7s 1ms/sample - loss: 0.4050 - accuracy: 0.8209 - val_loss: 0.5447 - val_accuracy: 0.7419
# Epoch 26/30
# 4909/4909 [==============================] - 7s 1ms/sample - loss: 0.3977 - accuracy: 0.8242 - val_loss: 0.5520 - val_accuracy: 0.7500
# Epoch 27/30
# 4909/4909 [==============================] - 7s 1ms/sample - loss: 0.3904 - accuracy: 0.8248 - val_loss: 0.5466 - val_accuracy: 0.7533
# Epoch 28/30
# 4909/4909 [==============================] - 7s 1ms/sample - loss: 0.3832 - accuracy: 0.8328 - val_loss: 0.5690 - val_accuracy: 0.7329
# Epoch 29/30
# 4909/4909 [==============================] - 7s 1ms/sample - loss: 0.3762 - accuracy: 0.8344 - val_loss: 0.5436 - val_accuracy: 0.7508
# Epoch 30/30
# 4909/4909 [==============================] - 7s 1ms/sample - loss: 0.3687 - accuracy: 0.8381 - val_loss: 0.5448 - val_accuracy: 0.7467
# 2046/2046 - 1s - loss: 0.5229 - accuracy: 0.7512
#
# Test accuracy: 0.7512219
# Target: 0, Predicted label: [0]

# %% [markdown]
# ### PLOTING CONFUSION MATRIX

# %%
from sklearn.metrics import confusion_matrix

yhat_probs = model.predict(X_test, verbose=0)
tt = np.argmax(yhat_probs, axis = 1)

cm=confusion_matrix(y_test, tt)
print(cm)
# Out:
# [[ 126 1216]
#  [  28  676]]

# %% [markdown]
# # Experiment : 4
# * MODEL 4

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
# import tensorflow.keras as keras
import tensorflow as tf
import tensorflow_hub as hub
import matplotlib.pylab as plt

DATA_PATH = "sick_sound.json"


def load_data(data_path):
    """Loads training dataset from json file.

        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    return X, y


def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs

        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()


def prepare_datasets(test_size, validation_size):
    """Loads data and splits it into train, validation and test sets.

    :param test_size (float): Value in [0, 1] indicating percentage of data set to allocate to test split
    :param validation_size (float): Value in [0, 1] indicating percentage of train set to allocate to validation split

    :return X_train (ndarray): Input training set
    :return X_validation (ndarray): Input validation set
    :return X_test (ndarray): Input test set
    :return y_train (ndarray): Target training set
    :return y_validation (ndarray): Target validation set
    :return y_test (ndarray): Target test set
    """

    # load data
    X, y = load_data(DATA_PATH)

    # create train, validation and test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # add an axis to input sets
    X_train = X_train[..., np.newaxis]
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test


def build_model(input_shape):
    """Generates CNN model

    :param input_shape (tuple): Shape of input set
    :return model: CNN model
    """

    # build network topology
    model = keras.Sequential()

    # 1st conv layer
    model.add(keras.layers.Conv2D(64, (2, 2), padding='same', activation='relu', input_shape=input_shape))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 2nd conv layer
    model.add(keras.layers.Conv2D(64, (2, 2), padding='same', activation='relu'))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 3rd conv layer
    model.add(keras.layers.Conv2D(32, (2, 2), padding='same', activation='relu'))
    model.add(keras.layers.BatchNormalization())
    
    # 4th conv layer
    model.add(keras.layers.Conv2D(32, (2, 2), padding='same', activation='relu'))
    model.add(keras.layers.BatchNormalization())
    
#     base_model = tf.keras.applications.MobileNetV2(input_shape=input_shape,
#                                                include_top=False,
#                                                weights='imagenet')
    
#     base_model.trainable = False
    
#     model = tf.keras.Sequential([
#         base_model,
#         tf.keras.layers.Dense(112, activation='relu'),
#         tf.keras.layers.Dropout(0.3),
#         tf.keras.layers.Dense(64, activation='relu'),
#         tf.keras.layers.Dropout(0.3),
#         tf.keras.layers.Dense(1, activation='sigmoid')
#     ])

#     URL = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/2"
#     feature_extractor = hub.KerasLayer(URL,
#                                    input_shape= input_shape)
    
#     feature_extractor.trainable = False
    
    
#     model = tf.keras.Sequential([
#         feature_extractor,
#         tf.keras.layers.Dense(112, activation='relu'),
#         tf.keras.layers.Dropout(0.3),
#         tf.keras.layers.Dense(64, activation='relu'),
#         tf.keras.layers.Dropout(0.3),
#         tf.keras.layers.Dense(1, activation='sigmoid')
#     ])

    # flatten output and feed it into dense layer
    model.add(keras.layers.Flatten())
    
    model.add(keras.layers.Dense(256, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001)))
    model.add(keras.layers.Dropout(0.4))
    model.add(keras.layers.Dense(64, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001)))
    model.add(keras.layers.Dropout(0.3))

    # output layer
    model.add(keras.layers.Dense(2, activation='softmax'))

    return model



def predict(model, X, y):
    """Predict a single sample using the trained model

    :param model: Trained classifier
    :param X: Input data
    :param y (int): Target
    """

    # add a dimension to input data for sample - model.predict() expects a 4d array in this case
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)

    # perform prediction
    prediction = model.predict(X)

    # get index with max value
    predicted_index = np.argmax(prediction, axis=1)

    print("Target: {}, Predicted label: {}".format(y, predicted_index))


if __name__ == "__main__":

    # get train, validation, test splits
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2], 1)
    model = build_model(input_shape)
    
#     lr_schedule = tf.keras.optimizers.schedules.InverseTimeDecay(
#       0.001,
#       decay_steps=STEPS_PER_EPOCH*1000,
#       decay_rate=1,
#       staircase=False
#     )

    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
                    monitor='val_loss', factor=0.1, patience=3, verbose=1, mode='auto',
                    min_delta=0.0001, cooldown=0 #, min_lr=0.001
                )
    
    earlystop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=15, restore_best_weights = True, verbose=1)
    checkpoint = tf.keras.callbacks.ModelCheckpoint(
            "sickweight4.h5", monitor='val_loss', verbose=1, save_best_only=True,
            save_weights_only=True, mode='min', save_freq='epoch' 
        )

    callbacks = [reduce_lr, earlystop, checkpoint]
    
    # compile model
    optimizer = keras.optimizers.Adam(learning_rate=0.001)
    model.compile(optimizer=optimizer,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    

    model.summary()
    
    batch_size = 64
    # train model
    history = model.fit(X_train,
                        y_train,
                        batch_size=batch_size,
                        steps_per_epoch = int(np.ceil(len(X_train) / float(batch_size))), #  len(X_train) // batch_size,
                        validation_data=(X_validation, y_validation),
                        validation_steps= int(np.ceil(len(X_validation) / float(batch_size))),
                        epochs=50,
                        callbacks=callbacks,
                       )

    # plot accuracy/error for training and validation
    plot_history(history)

    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)

    # pick a sample to predict from the test set
    X_to_predict = X_test[0]
    y_to_predict = y_test[0]

    # predict sample
    predict(model, X_to_predict, y_to_predict)
# Out:
# Model: "sequential_64"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_191 (Conv2D)          (None, 108, 13, 64)       640
# _________________________________________________________________
# max_pooling2d_139 (MaxPoolin (None, 54, 7, 64)         0
# _________________________________________________________________
# batch_normalization_165 (Bat (None, 54, 7, 64)         256
# _________________________________________________________________
# conv2d_192 (Conv2D)          (None, 54, 7, 64)         36928
# _________________________________________________________________
# max_pooling2d_140 (MaxPoolin (None, 27, 4, 64)         0
# _________________________________________________________________
# batch_normalization_166 (Bat (None, 27, 4, 64)         256
# _________________________________________________________________
# conv2d_193 (Conv2D)          (None, 27, 4, 32)         8224
# _________________________________________________________________
# batch_normalization_167 (Bat (None, 27, 4, 32)         128
# _________________________________________________________________
# conv2d_194 (Conv2D)          (None, 27, 4, 32)         4128
# _________________________________________________________________
# batch_normalization_168 (Bat (None, 27, 4, 32)         128
# _________________________________________________________________
# flatten_32 (Flatten)         (None, 3456)              0
# _________________________________________________________________
# dense_100 (Dense)            (None, 256)               884992
# _________________________________________________________________
# dropout_61 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_101 (Dense)            (None, 64)                16448
# _________________________________________________________________
# dropout_62 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_102 (Dense)            (None, 2)                 130
# =================================================================
# Total params: 952,258
# Trainable params: 951,874
# Non-trainable params: 384
# _________________________________________________________________
# Train on 4909 samples, validate on 1228 samples
# Epoch 1/50
# 4864/4909 [============================>.] - ETA: 0s - loss: 1.2984 - accuracy: 0.6145
# Epoch 00001: val_loss improved from inf to 1.16911, saving model to sickweight4.h5
# 4909/4909 [==============================] - 25s 5ms/sample - loss: 1.2978 - accuracy: 0.6136 - val_loss: 1.1691 - val_accuracy: 0.6531
# Epoch 2/50
# 4864/4909 [============================>.] - ETA: 0s - loss: 1.0965 - accuracy: 0.6495
# Epoch 00002: val_loss improved from 1.16911 to 1.04541, saving model to sickweight4.h5
# 4909/4909 [==============================] - 25s 5ms/sample - loss: 1.0967 - accuracy: 0.6486 - val_loss: 1.0454 - val_accuracy: 0.6743
# Epoch 3/50
# 4864/4909 [============================>.] - ETA: 0s - loss: 0.9988 - accuracy: 0.6721
# Epoch 00003: val_loss improved from 1.04541 to 0.95557, saving model to sickweight4.h5
# 4909/4909 [==============================] - 26s 5ms/sample - loss: 0.9984 - accuracy: 0.6714 - val_loss: 0.9556 - val_accuracy: 0.6832
# Epoch 4/50
# 4864/4909 [============================>.] - ETA: 0s - loss: 0.9041 - accuracy: 0.6875
# Epoch 00004: val_loss improved from 0.95557 to 0.86850, saving model to sickweight4.h5
# 4909/4909 [==============================] - 25s 5ms/sample - loss: 0.9041 - accuracy: 0.6879 - val_loss: 0.8685 - val_accuracy: 0.7223
# Epoch 5/50
# 4864/4909 [============================>.] - ETA: 0s - loss: 0.8312 - accuracy: 0.7116
# Epoch 00005: val_loss improved from 0.86850 to 0.79460, saving model to sickweight4.h5
# 4909/4909 [==============================] - 26s 5ms/sample - loss: 0.8308 - accuracy: 0.7120 - val_loss: 0.7946 - val_accuracy: 0.7117
# Epoch 6/50
# 4864/4909 [============================>.] - ETA: 0s - loss: 0.7601 - accuracy: 0.7354
# Epoch 00006: val_loss did not improve from 0.79460
# 4909/4909 [==============================] - 24s 5ms/sample - loss: 0.7593 - accuracy: 0.7358 - val_loss: 0.7991 - val_accuracy: 0.6800
# Epoch 7/50
# 4864/4909 [============================>.] - ETA: 0s - loss: 0.7048 - accuracy: 0.7506
# Epoch 00007: val_loss improved from 0.79460 to 0.66314, saving model to sickweight4.h5
# 4909/4909 [==============================] - 28s 6ms/sample - loss: 0.7040 - accuracy: 0.7515 - val_loss: 0.6631 - val_accuracy: 0.7809
# Epoch 8/50
# 4864/4909 [============================>.] - ETA: 0s - loss: 0.6572 - accuracy: 0.7738
# Epoch 00008: val_loss improved from 0.66314 to 0.64370, saving model to sickweight4.h5
# 4909/4909 [==============================] - 26s 5ms/sample - loss: 0.6565 - accuracy: 0.7743 - val_loss: 0.6437 - val_accuracy: 0.7679
# Epoch 9/50
# 4864/4909 [============================>.] - ETA: 0s - loss: 0.6131 - accuracy: 0.7876
# Epoch 00009: val_loss did not improve from 0.64370
# 4909/4909 [==============================] - 27s 5ms/sample - loss: 0.6136 - accuracy: 0.7867 - val_loss: 0.7001 - val_accuracy: 0.7191
# Epoch 10/50
# 4864/4909 [============================>.] - ETA: 0s - loss: 0.5895 - accuracy: 0.7932
# Epoch 00010: val_loss did not improve from 0.64370
# 4909/4909 [==============================] - 27s 6ms/sample - loss: 0.5910 - accuracy: 0.7926 - val_loss: 0.6712 - val_accuracy: 0.7476
# Epoch 11/50
# 4864/4909 [============================>.] - ETA: 0s - loss: 0.5726 - accuracy: 0.7934
# Epoch 00011: val_loss improved from 0.64370 to 0.61196, saving model to sickweight4.h5
# 4909/4909 [==============================] - 26s 5ms/sample - loss: 0.5724 - accuracy: 0.7938 - val_loss: 0.6120 - val_accuracy: 0.7736
# Epoch 12/50
# 4864/4909 [============================>.] - ETA: 0s - loss: 0.5377 - accuracy: 0.8088
# Epoch 00012: val_loss did not improve from 0.61196
# 4909/4909 [==============================] - 26s 5ms/sample - loss: 0.5395 - accuracy: 0.8077 - val_loss: 0.6427 - val_accuracy: 0.7630
# Epoch 13/50
# 4864/4909 [============================>.] - ETA: 0s - loss: 0.5397 - accuracy: 0.8078
# Epoch 00013: val_loss improved from 0.61196 to 0.60048, saving model to sickweight4.h5
# 4909/4909 [==============================] - 25s 5ms/sample - loss: 0.5389 - accuracy: 0.8083 - val_loss: 0.6005 - val_accuracy: 0.7752
# Epoch 14/50
# 4864/4909 [============================>.] - ETA: 0s - loss: 0.5177 - accuracy: 0.8263
# Epoch 00014: val_loss did not improve from 0.60048
# 4909/4909 [==============================] - 26s 5ms/sample - loss: 0.5166 - accuracy: 0.8268 - val_loss: 0.6170 - val_accuracy: 0.7923
# Epoch 15/50
# 4864/4909 [============================>.] - ETA: 0s - loss: 0.4891 - accuracy: 0.8361
# Epoch 00015: val_loss did not improve from 0.60048
# 4909/4909 [==============================] - 25s 5ms/sample - loss: 0.4895 - accuracy: 0.8364 - val_loss: 0.6680 - val_accuracy: 0.7761
# Epoch 16/50
# 4864/4909 [============================>.] - ETA: 0s - loss: 0.4929 - accuracy: 0.8417
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00016: val_loss did not improve from 0.60048
# 4909/4909 [==============================] - 24s 5ms/sample - loss: 0.4928 - accuracy: 0.8417 - val_loss: 0.6877 - val_accuracy: 0.7427
# Epoch 17/50
# 4864/4909 [============================>.] - ETA: 0s - loss: 0.4442 - accuracy: 0.8740
# Epoch 00017: val_loss did not improve from 0.60048
# 4909/4909 [==============================] - 26s 5ms/sample - loss: 0.4437 - accuracy: 0.8741 - val_loss: 0.6252 - val_accuracy: 0.8013
# Epoch 18/50
# 4864/4909 [============================>.] - ETA: 0s - loss: 0.3930 - accuracy: 0.8892
# Epoch 00018: val_loss did not improve from 0.60048
# 4909/4909 [==============================] - 25s 5ms/sample - loss: 0.3932 - accuracy: 0.8890 - val_loss: 0.6404 - val_accuracy: 0.8021
# Epoch 19/50
# 4864/4909 [============================>.] - ETA: 0s - loss: 0.3654 - accuracy: 0.9050
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00019: val_loss did not improve from 0.60048
# 4909/4909 [==============================] - 24s 5ms/sample - loss: 0.3650 - accuracy: 0.9053 - val_loss: 0.6615 - val_accuracy: 0.7972
# Epoch 20/50
# 4864/4909 [============================>.] - ETA: 0s - loss: 0.3414 - accuracy: 0.9194
# Epoch 00020: val_loss did not improve from 0.60048
# 4909/4909 [==============================] - 24s 5ms/sample - loss: 0.3417 - accuracy: 0.9189 - val_loss: 0.6661 - val_accuracy: 0.8005
# Epoch 21/50
# 4864/4909 [============================>.] - ETA: 0s - loss: 0.3435 - accuracy: 0.9147
# Epoch 00021: val_loss did not improve from 0.60048
# 4909/4909 [==============================] - 26s 5ms/sample - loss: 0.3438 - accuracy: 0.9149 - val_loss: 0.6717 - val_accuracy: 0.7989
# Epoch 22/50
# 4864/4909 [============================>.] - ETA: 0s - loss: 0.3396 - accuracy: 0.9180
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 00022: val_loss did not improve from 0.60048
# 4909/4909 [==============================] - 27s 5ms/sample - loss: 0.3390 - accuracy: 0.9185 - val_loss: 0.6755 - val_accuracy: 0.7980
# Epoch 23/50
# 4864/4909 [============================>.] - ETA: 0s - loss: 0.3363 - accuracy: 0.9186
# Epoch 00023: val_loss did not improve from 0.60048
# 4909/4909 [==============================] - 32s 6ms/sample - loss: 0.3362 - accuracy: 0.9187 - val_loss: 0.6769 - val_accuracy: 0.7980
# Epoch 24/50
# 4864/4909 [============================>.] - ETA: 0s - loss: 0.3392 - accuracy: 0.9159
# Epoch 00024: val_loss did not improve from 0.60048
# 4909/4909 [==============================] - 26s 5ms/sample - loss: 0.3389 - accuracy: 0.9161 - val_loss: 0.6779 - val_accuracy: 0.7980
# Epoch 25/50
# 4864/4909 [============================>.] - ETA: 0s - loss: 0.3375 - accuracy: 0.9176
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
#
# Epoch 00025: val_loss did not improve from 0.60048
# 4909/4909 [==============================] - 26s 5ms/sample - loss: 0.3373 - accuracy: 0.9173 - val_loss: 0.6782 - val_accuracy: 0.7972
# Epoch 26/50
# 4864/4909 [============================>.] - ETA: 0s - loss: 0.3341 - accuracy: 0.9192
# Epoch 00026: val_loss did not improve from 0.60048
# 4909/4909 [==============================] - 26s 5ms/sample - loss: 0.3337 - accuracy: 0.9193 - val_loss: 0.6787 - val_accuracy: 0.7980
# Epoch 27/50
# 4864/4909 [============================>.] - ETA: 0s - loss: 0.3340 - accuracy: 0.9190
# Epoch 00027: val_loss did not improve from 0.60048
# 4909/4909 [==============================] - 27s 6ms/sample - loss: 0.3336 - accuracy: 0.9187 - val_loss: 0.6788 - val_accuracy: 0.7989
# Epoch 28/50
# 4864/4909 [============================>.] - ETA: 0s - loss: 0.3388 - accuracy: 0.9192
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# Restoring model weights from the end of the best epoch.
#
# Epoch 00028: val_loss did not improve from 0.60048
# 4909/4909 [==============================] - 26s 5ms/sample - loss: 0.3379 - accuracy: 0.9197 - val_loss: 0.6789 - val_accuracy: 0.7989
# Epoch 00028: early stopping
# 2046/2046 - 2s - loss: 0.6003 - accuracy: 0.7805
#
# Test accuracy: 0.7805474
# Target: 0, Predicted label: [0]

# %%
# DOING MANUAL PREDICTIONS:

input_shape = (X_train.shape[1], X_train.shape[2], 1)
model = build_model(input_shape)

X_to_predict = X_test[12]
y_to_predict = y_test[12]

predict(model, X_to_predict, y_to_predict)
# Out:
# Target: 1, Predicted label: [1]

# %%
# PLOTTING CONFUSION MATRIX

from sklearn.metrics import confusion_matrix

yhat_probs = model.predict(X_test, verbose=0)
tt = np.argmax(yhat_probs, axis = 1)

cm=confusion_matrix(y_test, tt)
print(cm)
# Out:
# [[ 126 1216]
#  [  28  676]]

# %% [markdown]
# # ALERT
# ### BELOW IS THE TESTING AREA, DON't TRY TO RUN THAT CODE.

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

DATA_PATH = "breath_sound.json"


def load_data(data_path):
    """Loads training dataset from json file.

        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    return X, y


def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs

        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()


def prepare_datasets(test_size, validation_size):
    """Loads data and splits it into train, validation and test sets.

    :param test_size (float): Value in [0, 1] indicating percentage of data set to allocate to test split
    :param validation_size (float): Value in [0, 1] indicating percentage of train set to allocate to validation split

    :return X_train (ndarray): Input training set
    :return X_validation (ndarray): Input validation set
    :return X_test (ndarray): Input test set
    :return y_train (ndarray): Target training set
    :return y_validation (ndarray): Target validation set
    :return y_test (ndarray): Target test set
    """

    # load data
    X, y = load_data(DATA_PATH)

    # create train, validation and test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # add an axis to input sets
    X_train = X_train[..., np.newaxis]
    print(X_train.shape)
    X_validation = X_validation[..., np.newaxis]
    print(X_validation.shape)
    X_test = X_test[..., np.newaxis]
    print(X_test.shape)

    return X_train, X_validation, X_test, y_train, y_validation, y_test


def build_model(input_shape):
    """Generates CNN model

    :param input_shape (tuple): Shape of input set
    :return model: CNN model
    """

    # build network topology
    model = keras.Sequential()

    # 1st conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 2nd conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu'))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 3rd conv layer
    model.add(keras.layers.Conv2D(32, (2, 2), activation='relu'))
    model.add(keras.layers.MaxPooling2D((2, 2), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # flatten output and feed it into dense layer
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dropout(0.3))

    # output layer
    model.add(keras.layers.Dense(2, activation='sigmoid'))
    # is me problem hau blc sigmoid hamesha ak hi single output deta hai so dense should be 1. 

    return model


def predict(model, X, y):
    """Predict a single sample using the trained model

    :param model: Trained classifier
    :param X: Input data
    :param y (int): Target
    """

    # add a dimension to input data for sample - model.predict() expects a 4d array in this case
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)

    # perform prediction
    prediction = model.predict(X)

    # get index with max value
    predicted_index = np.argmax(prediction, axis=1)

    print("Target: {}, Predicted label: {}".format(y, predicted_index))


if __name__ == "__main__":

    # get train, validation, test splits
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2], 1)
    model = build_model(input_shape)

    # compile model
    optimizer = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimizer,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=32, epochs=30)

    # plot accuracy/error for training and validation
    plot_history(history)

    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)

    # pick a sample to predict from the test set
    X_to_predict = X_test[0]
    y_to_predict = y_test[0]

    # predict sample
    predict(model, X_to_predict, y_to_predict)
# Out:
# (14, 197, 13, 1)
# (4, 197, 13, 1)
# (7, 197, 13, 1)
# Model: "sequential_33"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_102 (Conv2D)          (None, 195, 11, 32)       320
# _________________________________________________________________
# max_pooling2d_77 (MaxPooling (None, 98, 6, 32)         0
# _________________________________________________________________
# batch_normalization_77 (Batc (None, 98, 6, 32)         128
# _________________________________________________________________
# conv2d_103 (Conv2D)          (None, 96, 4, 32)         9248
# _________________________________________________________________
# max_pooling2d_78 (MaxPooling (None, 48, 2, 32)         0
# _________________________________________________________________
# batch_normalization_78 (Batc (None, 48, 2, 32)         128
# _________________________________________________________________
# conv2d_104 (Conv2D)          (None, 47, 1, 32)         4128
# _________________________________________________________________
# max_pooling2d_79 (MaxPooling (None, 24, 1, 32)         0
# _________________________________________________________________
# batch_normalization_79 (Batc (None, 24, 1, 32)         128
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 768)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 64)                49216
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_20 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 63,426
# Trainable params: 63,234
# Non-trainable params: 192
# _________________________________________________________________
# Train on 14 samples, validate on 4 samples
# Epoch 1/30
# 14/14 [==============================] - 1s 95ms/sample - loss: 0.8285 - accuracy: 0.4286 - val_loss: 0.7456 - val_accuracy: 0.5000
# Epoch 2/30
# 14/14 [==============================] - 0s 5ms/sample - loss: 0.6866 - accuracy: 0.6429 - val_loss: 0.6370 - val_accuracy: 0.5000
# Epoch 3/30
# 14/14 [==============================] - 0s 5ms/sample - loss: 0.5165 - accuracy: 0.8571 - val_loss: 0.6029 - val_accuracy: 0.5000
# Epoch 4/30
# 14/14 [==============================] - 0s 8ms/sample - loss: 0.5710 - accuracy: 0.7857 - val_loss: 0.5909 - val_accuracy: 0.5000
# Epoch 5/30
# 14/14 [==============================] - 0s 6ms/sample - loss: 0.5277 - accuracy: 0.9286 - val_loss: 0.5848 - val_accuracy: 0.5000
# Epoch 6/30
# 14/14 [==============================] - 0s 7ms/sample - loss: 0.4473 - accuracy: 0.9286 - val_loss: 0.5834 - val_accuracy: 0.5000
# Epoch 7/30
# 14/14 [==============================] - 0s 6ms/sample - loss: 0.4049 - accuracy: 1.0000 - val_loss: 0.5833 - val_accuracy: 0.5000
# Epoch 8/30
# 14/14 [==============================] - 0s 5ms/sample - loss: 0.3122 - accuracy: 1.0000 - val_loss: 0.5823 - val_accuracy: 0.5000
# Epoch 9/30
# 14/14 [==============================] - 0s 5ms/sample - loss: 0.3293 - accuracy: 0.9286 - val_loss: 0.5806 - val_accuracy: 0.5000
# Epoch 10/30
# 14/14 [==============================] - 0s 5ms/sample - loss: 0.2727 - accuracy: 1.0000 - val_loss: 0.5782 - val_accuracy: 0.7500
# Epoch 11/30
# 14/14 [==============================] - 0s 5ms/sample - loss: 0.2005 - accuracy: 1.0000 - val_loss: 0.5754 - val_accuracy: 1.0000
# Epoch 12/30
# 14/14 [==============================] - 0s 5ms/sample - loss: 0.2637 - accuracy: 1.0000 - val_loss: 0.5725 - val_accuracy: 1.0000
# Epoch 13/30
# 14/14 [==============================] - 0s 6ms/sample - loss: 0.2373 - accuracy: 1.0000 - val_loss: 0.5689 - val_accuracy: 1.0000
# Epoch 14/30
# 14/14 [==============================] - 0s 8ms/sample - loss: 0.1690 - accuracy: 1.0000 - val_loss: 0.5653 - val_accuracy: 1.0000
# Epoch 15/30
# 14/14 [==============================] - 0s 5ms/sample - loss: 0.1379 - accuracy: 1.0000 - val_loss: 0.5616 - val_accuracy: 1.0000
# Epoch 16/30
# 14/14 [==============================] - 0s 5ms/sample - loss: 0.1522 - accuracy: 1.0000 - val_loss: 0.5576 - val_accuracy: 1.0000
# Epoch 17/30
# 14/14 [==============================] - 0s 5ms/sample - loss: 0.1192 - accuracy: 1.0000 - val_loss: 0.5541 - val_accuracy: 1.0000
# Epoch 18/30
# 14/14 [==============================] - 0s 5ms/sample - loss: 0.1377 - accuracy: 1.0000 - val_loss: 0.5508 - val_accuracy: 1.0000
# Epoch 19/30
# 14/14 [==============================] - 0s 4ms/sample - loss: 0.1280 - accuracy: 1.0000 - val_loss: 0.5481 - val_accuracy: 1.0000
# Epoch 20/30
# 14/14 [==============================] - 0s 4ms/sample - loss: 0.1182 - accuracy: 1.0000 - val_loss: 0.5453 - val_accuracy: 1.0000
# Epoch 21/30
# 14/14 [==============================] - 0s 5ms/sample - loss: 0.1032 - accuracy: 1.0000 - val_loss: 0.5427 - val_accuracy: 1.0000
# Epoch 22/30
# 14/14 [==============================] - 0s 5ms/sample - loss: 0.1358 - accuracy: 1.0000 - val_loss: 0.5403 - val_accuracy: 1.0000
# Epoch 23/30
# 14/14 [==============================] - 0s 6ms/sample - loss: 0.0613 - accuracy: 1.0000 - val_loss: 0.5380 - val_accuracy: 1.0000
# Epoch 24/30
# 14/14 [==============================] - 0s 6ms/sample - loss: 0.1491 - accuracy: 1.0000 - val_loss: 0.5356 - val_accuracy: 1.0000
# Epoch 25/30
# 14/14 [==============================] - 0s 5ms/sample - loss: 0.0774 - accuracy: 1.0000 - val_loss: 0.5331 - val_accuracy: 1.0000
# Epoch 26/30
# 14/14 [==============================] - 0s 5ms/sample - loss: 0.0586 - accuracy: 1.0000 - val_loss: 0.5305 - val_accuracy: 1.0000
# Epoch 27/30
# 14/14 [==============================] - 0s 5ms/sample - loss: 0.0402 - accuracy: 1.0000 - val_loss: 0.5279 - val_accuracy: 1.0000
# Epoch 28/30
# 14/14 [==============================] - 0s 5ms/sample - loss: 0.0413 - accuracy: 1.0000 - val_loss: 0.5252 - val_accuracy: 1.0000
# Epoch 29/30
# 14/14 [==============================] - 0s 5ms/sample - loss: 0.0613 - accuracy: 1.0000 - val_loss: 0.5223 - val_accuracy: 1.0000
# Epoch 30/30
# 14/14 [==============================] - 0s 5ms/sample - loss: 0.0313 - accuracy: 1.0000 - val_loss: 0.5201 - val_accuracy: 1.0000
# 7/7 - 0s - loss: 0.5612 - accuracy: 0.8571
#
# Test accuracy: 0.85714287
# Target: 1, Predicted label: [1]

# %%
X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

# create network
input_shape = (X_train.shape[1], X_train.shape[2], 1)
model = build_model(input_shape)

X_to_predict = X_test[6]
y_to_predict = y_test[6]

predict(model, X_to_predict, y_to_predict)
# Out:
# (14, 197, 13, 1)
# (4, 197, 13, 1)
# (7, 197, 13, 1)
# Target: 1, Predicted label: [1]
